# %% [markdown]
# ## Test of different numeric settings and their influence on cenvergence and the recirculation bubble

# %% [markdown]
# ### 1 Test

# %% [markdown]
# ### 1.1 Setup

# %% [markdown]
# #### 1.1.1 1 Setup

# %% [markdown]
# - time 0.015s
# - nOuterCorrecters of the pimple algorithm is 10
# - relaxation p is 0.5
# - gradSchemes is set to cellLimeted Gauss 1.0

# %% [markdown]
# ### 1.2 Results

# %% [markdown]
# #### 1.2.1 Recirculation bubble at 0.015s

# %% [markdown]
# ![alt text](time_0.015.png)

# %% [markdown]
# #### 1.2.2 P field at the plane between the main and outlet block at 0.015s

# %% [markdown]
# ![alt text](gradP_time_0.015.png)

# %% [markdown]
# #### 1.2.3 Residuals

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.2.4 Wall shear stress at final time

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.2.5 Pressure difference over the diffusor

# %% [markdown]
# ![image.png](attachment:image.png)
